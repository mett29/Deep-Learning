# %%
import os.path
import re
import hashlib
import tensorflow as tf
from tensorflow import gfile
from tensorflow import compat
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import cv2
import numpy as np

# %%
"""
I took this function from 'https://github.com/loicmarie/sign-language-alphabet-recognizer', check it out!
I also took the dataset, although I splitted it in a different way.
"""

MAX_NUM_IMAGES_PER_CLASS = 2 ** 27 - 1  # ~134M

def create_image_lists(image_dir, testing_percentage, validation_percentage):
    """
    Brief:
        Builds a list of training images from the file system.
        Analyzes the sub folders in the image directory, splits them into stable
        training, testing, and validation sets, and returns a data structure
        describing the lists of images for each label and their paths.
    Args:
        image_dir: String path to a folder containing subfolders of images.
        testing_percentage: Integer percentage of the images to reserve for tests.
        validation_percentage: Integer percentage of images reserved for validation.
    Returns:
        A dictionary containing an entry for each label subfolder, with images split
        into training, testing, and validation sets within each label.
    """
    if not gfile.Exists(image_dir):
        print("Image directory '" + image_dir + "' not found.")
        return None
    result = {}
    sub_dirs = [x[0] for x in gfile.Walk(image_dir)]
    # The root directory comes first, so skip it.
    is_root_dir = True
    for sub_dir in sub_dirs:
        if is_root_dir:
            is_root_dir = False
            continue
        extensions = ['jpg', 'jpeg', 'JPG', 'JPEG']
        file_list = []
        dir_name = os.path.basename(sub_dir)
        if dir_name == image_dir:
            continue
        print("Looking for images in '" + dir_name + "'")
        for extension in extensions:
            file_glob = os.path.join(image_dir, dir_name, '*.' + extension)
            file_list.extend(gfile.Glob(file_glob))
        if not file_list:
            print('No files found')
            continue
        if len(file_list) < 20:
            print('WARNING: Folder has less than 20 images, which may cause issues.')
        elif len(file_list) > MAX_NUM_IMAGES_PER_CLASS:
            print('WARNING: Folder {} has more than {} images. Some images will '
                  'never be selected.'.format(dir_name, MAX_NUM_IMAGES_PER_CLASS))
        label_name = re.sub(r'[^a-z0-9]+', ' ', dir_name.lower())
        training_images = []
        testing_images = []
        validation_images = []
        for file_name in file_list:
            base_name = os.path.basename(file_name)
            # We want to ignore anything after '_nohash_' in the file name when
            # deciding which set to put an image in, the data set creator has a way of
            # grouping photos that are close variations of each other. For example
            # this is used in the plant disease data set to group multiple pictures of
            # the same leaf.
            hash_name = re.sub(r'_nohash_.*$', '', file_name)
            # This looks a bit magical, but we need to decide whether this file should
            # go into the training, testing, or validation sets, and we want to keep
            # existing files in the same set even if more files are subsequently
            # added.
            # To do that, we need a stable way of deciding based on just the file name
            # itself, so we do a hash of that and then use that to generate a
            # probability value that we use to assign it.
            hash_name_hashed = hashlib.sha1(compat.as_bytes(hash_name)).hexdigest()
            percentage_hash = ((int(hash_name_hashed, 16) %
                                (MAX_NUM_IMAGES_PER_CLASS + 1)) *
                             (100.0 / MAX_NUM_IMAGES_PER_CLASS))
            if percentage_hash < validation_percentage:
                validation_images.append(base_name)
            elif percentage_hash < (testing_percentage + validation_percentage):
                testing_images.append(base_name)
            else:
                training_images.append(base_name)
        result[label_name] = {
            'dir': dir_name,
            'training': training_images,
            'testing': testing_images,
            'validation': validation_images,
            }
    return result

# %%
result = create_image_lists("dataset", 20, 20)
# Out:
# Looking for images in 'A'
# Looking for images in 'B'
# Looking for images in 'C'
# Looking for images in 'D'
# Looking for images in 'del'
# Looking for images in 'E'
# Looking for images in 'F'
# Looking for images in 'G'
# Looking for images in 'H'
# Looking for images in 'I'
# Looking for images in 'J'
# Looking for images in 'K'
# Looking for images in 'L'
# Looking for images in 'M'
# Looking for images in 'N'
# Looking for images in 'nothing'
# Looking for images in 'O'
# Looking for images in 'P'
# Looking for images in 'Q'
# Looking for images in 'R'
# Looking for images in 'S'
# Looking for images in 'space'
# Looking for images in 'T'
# Looking for images in 'U'
# Looking for images in 'V'
# Looking for images in 'W'
# Looking for images in 'X'
# Looking for images in 'Y'
# Looking for images in 'Z'

# %%
# Let's check how we can access the data
result['a']['training']
# Out:
# ['A10.jpg',
#  'A100.jpg',
#  'A1001.jpg',
#  'A1003.jpg',
#  'A1004.jpg',
#  'A1005.jpg',
#  'A1007.jpg',
#  'A1008.jpg',
#  'A1009.jpg',
#  'A1010.jpg',
#  'A1011.jpg',
#  'A1013.jpg',
#  'A1016.jpg',
#  'A1017.jpg',
#  'A1018.jpg',
#  'A1020.jpg',
#  'A1022.jpg',
#  'A1025.jpg',
#  'A1026.jpg',
#  'A1028.jpg',
#  'A103.jpg',
#  'A1030.jpg',
#  'A1031.jpg',
#  'A1032.jpg',
#  'A1033.jpg',
#  'A1037.jpg',
#  'A1038.jpg',
#  'A1039.jpg',
#  'A1042.jpg',
#  'A1043.jpg',
#  'A1045.jpg',
#  'A1046.jpg',
#  'A1048.jpg',
#  'A1050.jpg',
#  'A1054.jpg',
#  'A1056.jpg',
#  'A1057.jpg',
#  'A1058.jpg',
#  'A1061.jpg',
#  'A1063.jpg',
#  'A1064.jpg',
#  'A1065.jpg',
#  'A1066.jpg',
#  'A1067.jpg',
#  'A1068.jpg',
#  'A1069.jpg',
#  'A1070.jpg',
#  'A1071.jpg',
#  'A1072.jpg',
#  'A1074.jpg',
#  'A1075.jpg',
#  'A1076.jpg',
#  'A1077.jpg',
#  'A108.jpg',
#  'A1081.jpg',
#  'A1083.jpg',
#  'A1085.jpg',
#  'A1086.jpg',
#  'A1088.jpg',
#  'A1089.jpg',
#  'A109.jpg',
#  'A1090.jpg',
#  'A1092.jpg',
#  'A1093.jpg',
#  'A1095.jpg',
#  'A1096.jpg',
#  'A1097.jpg',
#  'A1099.jpg',
#  'A110.jpg',
#  'A1100.jpg',
#  'A1101.jpg',
#  'A1104.jpg',
#  'A1105.jpg',
#  'A1106.jpg',
#  'A1107.jpg',
#  'A1108.jpg',
#  'A1109.jpg',
#  'A1110.jpg',
#  'A1111.jpg',
#  'A1112.jpg',
#  'A1113.jpg',
#  'A1117.jpg',
#  'A1118.jpg',
#  'A1120.jpg',
#  'A1121.jpg',
#  'A1122.jpg',
#  'A1123.jpg',
#  'A1128.jpg',
#  'A1129.jpg',
#  'A113.jpg',
#  'A1132.jpg',
#  'A1133.jpg',
#  'A1135.jpg',
#  'A1136.jpg',
#  'A1137.jpg',
#  'A1139.jpg',
#  'A114.jpg',
#  'A1140.jpg',
#  'A1141.jpg',
#  'A1142.jpg',
#  'A1143.jpg',
#  'A1145.jpg',
#  'A1146.jpg',
#  'A1147.jpg',
#  'A1148.jpg',
#  'A1151.jpg',
#  'A1152.jpg',
#  'A1153.jpg',
#  'A1155.jpg',
#  'A1158.jpg',
#  'A116.jpg',
#  'A1165.jpg',
#  'A1166.jpg',
#  'A1167.jpg',
#  'A1168.jpg',
#  'A1169.jpg',
#  'A117.jpg',
#  'A1174.jpg',
#  'A1175.jpg',
#  'A1176.jpg',
#  'A1177.jpg',
#  'A1178.jpg',
#  'A1179.jpg',
#  'A118.jpg',
#  'A1183.jpg',
#  'A1185.jpg',
#  'A1189.jpg',
#  'A119.jpg',
#  'A1190.jpg',
#  'A1192.jpg',
#  'A1193.jpg',
#  'A1194.jpg',
#  'A1195.jpg',
#  'A1197.jpg',
#  'A1198.jpg',
#  'A1199.jpg',
#  'A120.jpg',
#  'A1200.jpg',
#  'A1201.jpg',
#  'A1202.jpg',
#  'A1205.jpg',
#  'A1206.jpg',
#  'A1208.jpg',
#  'A1211.jpg',
#  'A1213.jpg',
#  'A1215.jpg',
#  'A1217.jpg',
#  'A1218.jpg',
#  'A1219.jpg',
#  'A122.jpg',
#  'A1223.jpg',
#  'A1226.jpg',
#  'A1227.jpg',
#  'A123.jpg',
#  'A1232.jpg',
#  'A1233.jpg',
#  'A1234.jpg',
#  'A1236.jpg',
#  'A1238.jpg',
#  'A1240.jpg',
#  'A1243.jpg',
#  'A1246.jpg',
#  'A1247.jpg',
#  'A125.jpg',
#  'A1250.jpg',
#  'A1251.jpg',
#  'A1253.jpg',
#  'A1254.jpg',
#  'A1255.jpg',
#  'A1257.jpg',
#  'A1258.jpg',
#  'A1259.jpg',
#  'A126.jpg',
#  'A1261.jpg',
#  'A1262.jpg',
#  'A1264.jpg',
#  'A1265.jpg',
#  'A1266.jpg',
#  'A1267.jpg',
#  'A1269.jpg',
#  'A127.jpg',
#  'A1270.jpg',
#  'A1271.jpg',
#  'A1272.jpg',
#  'A1273.jpg',
#  'A1275.jpg',
#  'A1276.jpg',
#  'A1277.jpg',
#  'A1279.jpg',
#  'A128.jpg',
#  'A1280.jpg',
#  'A1281.jpg',
#  'A1282.jpg',
#  'A1283.jpg',
#  'A1286.jpg',
#  'A1287.jpg',
#  'A1288.jpg',
#  'A1289.jpg',
#  'A129.jpg',
#  'A1290.jpg',
#  'A1292.jpg',
#  'A1293.jpg',
#  'A1294.jpg',
#  'A1295.jpg',
#  'A1296.jpg',
#  'A1297.jpg',
#  'A13.jpg',
#  'A130.jpg',
#  'A1300.jpg',
#  'A1304.jpg',
#  'A1305.jpg',
#  'A1306.jpg',
#  'A1309.jpg',
#  'A131.jpg',
#  'A1310.jpg',
#  'A1312.jpg',
#  'A1315.jpg',
#  'A1317.jpg',
#  'A1318.jpg',
#  'A1319.jpg',
#  'A132.jpg',
#  'A1320.jpg',
#  'A1322.jpg',
#  'A1323.jpg',
#  'A1324.jpg',
#  'A1326.jpg',
#  'A1327.jpg',
#  'A133.jpg',
#  'A1334.jpg',
#  'A1336.jpg',
#  'A1338.jpg',
#  'A134.jpg',
#  'A1340.jpg',
#  'A1342.jpg',
#  'A1345.jpg',
#  'A1347.jpg',
#  'A1348.jpg',
#  'A1349.jpg',
#  'A1352.jpg',
#  'A1353.jpg',
#  'A1356.jpg',
#  'A1357.jpg',
#  'A1358.jpg',
#  'A1359.jpg',
#  'A136.jpg',
#  'A1360.jpg',
#  'A1361.jpg',
#  'A1364.jpg',
#  'A1365.jpg',
#  'A1366.jpg',
#  'A1369.jpg',
#  'A137.jpg',
#  'A1372.jpg',
#  'A1373.jpg',
#  'A1375.jpg',
#  'A1377.jpg',
#  'A1378.jpg',
#  'A1379.jpg',
#  'A138.jpg',
#  'A1383.jpg',
#  'A1384.jpg',
#  'A1389.jpg',
#  'A139.jpg',
#  'A1390.jpg',
#  'A1394.jpg',
#  'A1395.jpg',
#  'A1396.jpg',
#  'A1397.jpg',
#  'A1398.jpg',
#  'A1399.jpg',
#  'A14.jpg',
#  'A140.jpg',
#  'A1403.jpg',
#  'A1404.jpg',
#  'A1406.jpg',
#  'A1408.jpg',
#  'A141.jpg',
#  'A1410.jpg',
#  'A1411.jpg',
#  'A1415.jpg',
#  'A1416.jpg',
#  'A1417.jpg',
#  'A1419.jpg',
#  'A142.jpg',
#  'A1420.jpg',
#  'A1422.jpg',
#  'A1425.jpg',
#  'A1427.jpg',
#  'A1429.jpg',
#  'A143.jpg',
#  'A1431.jpg',
#  'A1433.jpg',
#  'A1436.jpg',
#  'A1439.jpg',
#  'A1444.jpg',
#  'A1445.jpg',
#  'A1448.jpg',
#  'A145.jpg',
#  'A1450.jpg',
#  'A1451.jpg',
#  'A1453.jpg',
#  'A1454.jpg',
#  'A1455.jpg',
#  'A1457.jpg',
#  'A1459.jpg',
#  'A1460.jpg',
#  'A1462.jpg',
#  'A1463.jpg',
#  'A1464.jpg',
#  'A1465.jpg',
#  'A1466.jpg',
#  'A1468.jpg',
#  'A1469.jpg',
#  'A147.jpg',
#  'A1470.jpg',
#  'A1473.jpg',
#  'A1475.jpg',
#  'A1478.jpg',
#  'A1479.jpg',
#  'A1481.jpg',
#  'A1482.jpg',
#  'A1483.jpg',
#  'A1484.jpg',
#  'A1485.jpg',
#  'A1486.jpg',
#  'A1488.jpg',
#  'A1489.jpg',
#  'A149.jpg',
#  'A1491.jpg',
#  'A1492.jpg',
#  'A1493.jpg',
#  'A1494.jpg',
#  'A1497.jpg',
#  'A1498.jpg',
#  'A15.jpg',
#  'A1502.jpg',
#  'A1504.jpg',
#  'A1507.jpg',
#  'A1509.jpg',
#  'A1510.jpg',
#  'A1511.jpg',
#  'A1513.jpg',
#  'A1514.jpg',
#  'A1515.jpg',
#  'A1516.jpg',
#  'A1517.jpg',
#  'A1518.jpg',
#  'A152.jpg',
#  'A1520.jpg',
#  'A1521.jpg',
#  'A1522.jpg',
#  'A1523.jpg',
#  'A1524.jpg',
#  'A153.jpg',
#  'A1533.jpg',
#  'A1535.jpg',
#  'A1536.jpg',
#  'A1538.jpg',
#  'A1539.jpg',
#  'A1542.jpg',
#  'A1543.jpg',
#  'A1544.jpg',
#  'A1546.jpg',
#  'A1547.jpg',
#  'A155.jpg',
#  'A1551.jpg',
#  'A1552.jpg',
#  'A1553.jpg',
#  'A1554.jpg',
#  'A1555.jpg',
#  'A1556.jpg',
#  'A156.jpg',
#  'A1560.jpg',
#  'A1561.jpg',
#  'A1562.jpg',
#  'A1563.jpg',
#  'A1564.jpg',
#  'A1565.jpg',
#  'A1569.jpg',
#  'A1570.jpg',
#  'A1572.jpg',
#  'A1573.jpg',
#  'A1576.jpg',
#  'A1577.jpg',
#  'A1578.jpg',
#  'A158.jpg',
#  'A1581.jpg',
#  'A1582.jpg',
#  'A1585.jpg',
#  'A1586.jpg',
#  'A1589.jpg',
#  'A1590.jpg',
#  'A1591.jpg',
#  'A1593.jpg',
#  'A1595.jpg',
#  'A1596.jpg',
#  'A1597.jpg',
#  'A1598.jpg',
#  'A16.jpg',
#  'A1600.jpg',
#  'A1602.jpg',
#  'A1604.jpg',
#  'A1606.jpg',
#  'A1607.jpg',
#  'A1609.jpg',
#  'A1611.jpg',
#  'A1612.jpg',
#  'A1613.jpg',
#  'A1614.jpg',
#  'A1615.jpg',
#  'A1617.jpg',
#  'A1618.jpg',
#  'A1619.jpg',
#  'A162.jpg',
#  'A1620.jpg',
#  'A1622.jpg',
#  'A1623.jpg',
#  'A1624.jpg',
#  'A1625.jpg',
#  'A1626.jpg',
#  'A1627.jpg',
#  'A1628.jpg',
#  'A1629.jpg',
#  'A1630.jpg',
#  'A1631.jpg',
#  'A1632.jpg',
#  'A1633.jpg',
#  'A164.jpg',
#  'A1640.jpg',
#  'A1641.jpg',
#  'A1645.jpg',
#  'A1646.jpg',
#  'A1647.jpg',
#  'A1648.jpg',
#  'A165.jpg',
#  'A1650.jpg',
#  'A1652.jpg',
#  'A1653.jpg',
#  'A1654.jpg',
#  'A166.jpg',
#  'A1660.jpg',
#  'A1661.jpg',
#  'A1662.jpg',
#  'A1663.jpg',
#  'A1666.jpg',
#  'A1667.jpg',
#  'A1668.jpg',
#  'A1670.jpg',
#  'A1671.jpg',
#  'A1672.jpg',
#  'A1673.jpg',
#  'A1674.jpg',
#  'A1675.jpg',
#  'A1676.jpg',
#  'A168.jpg',
#  'A1680.jpg',
#  'A1682.jpg',
#  'A1684.jpg',
#  'A1687.jpg',
#  'A1689.jpg',
#  'A1691.jpg',
#  'A1692.jpg',
#  'A1695.jpg',
#  'A1696.jpg',
#  'A1697.jpg',
#  'A1698.jpg',
#  'A1699.jpg',
#  'A17.jpg',
#  'A170.jpg',
#  'A1700.jpg',
#  'A1702.jpg',
#  'A1705.jpg',
#  'A1706.jpg',
#  'A1709.jpg',
#  'A1710.jpg',
#  'A1711.jpg',
#  'A1715.jpg',
#  'A1716.jpg',
#  'A1717.jpg',
#  'A1719.jpg',
#  'A172.jpg',
#  'A1720.jpg',
#  'A1721.jpg',
#  'A1723.jpg',
#  'A1724.jpg',
#  'A1725.jpg',
#  'A1726.jpg',
#  'A1728.jpg',
#  'A1729.jpg',
#  'A1731.jpg',
#  'A1732.jpg',
#  'A1735.jpg',
#  'A1736.jpg',
#  'A1737.jpg',
#  'A1738.jpg',
#  'A1739.jpg',
#  'A174.jpg',
#  'A1741.jpg',
#  'A1742.jpg',
#  'A1743.jpg',
#  'A1745.jpg',
#  'A1747.jpg',
#  'A1748.jpg',
#  'A175.jpg',
#  'A1750.jpg',
#  'A1752.jpg',
#  'A1753.jpg',
#  'A1754.jpg',
#  'A1758.jpg',
#  'A1759.jpg',
#  'A1760.jpg',
#  'A1762.jpg',
#  'A1763.jpg',
#  'A1765.jpg',
#  'A1766.jpg',
#  'A1767.jpg',
#  'A1768.jpg',
#  'A1769.jpg',
#  'A1773.jpg',
#  'A1774.jpg',
#  'A1775.jpg',
#  'A1777.jpg',
#  'A1778.jpg',
#  'A1779.jpg',
#  'A1780.jpg',
#  'A1783.jpg',
#  'A1785.jpg',
#  'A1786.jpg',
#  'A1787.jpg',
#  'A1788.jpg',
#  'A1791.jpg',
#  'A1795.jpg',
#  'A1796.jpg',
#  'A1798.jpg',
#  'A18.jpg',
#  'A180.jpg',
#  'A1800.jpg',
#  'A1801.jpg',
#  'A1802.jpg',
#  'A1803.jpg',
#  'A1806.jpg',
#  'A1810.jpg',
#  'A1811.jpg',
#  'A1813.jpg',
#  'A1817.jpg',
#  'A182.jpg',
#  'A1822.jpg',
#  'A1823.jpg',
#  'A1825.jpg',
#  'A1826.jpg',
#  'A1829.jpg',
#  'A1831.jpg',
#  'A1832.jpg',
#  'A1833.jpg',
#  'A1836.jpg',
#  'A1837.jpg',
#  'A1839.jpg',
#  'A184.jpg',
#  'A1840.jpg',
#  'A1841.jpg',
#  'A1844.jpg',
#  'A1845.jpg',
#  'A1846.jpg',
#  'A1848.jpg',
#  'A1849.jpg',
#  'A185.jpg',
#  'A1850.jpg',
#  'A1851.jpg',
#  'A1852.jpg',
#  'A1854.jpg',
#  'A1855.jpg',
#  'A1857.jpg',
#  'A1858.jpg',
#  'A186.jpg',
#  'A1862.jpg',
#  'A1865.jpg',
#  'A1866.jpg',
#  'A1867.jpg',
#  'A1870.jpg',
#  'A1871.jpg',
#  'A1873.jpg',
#  'A1874.jpg',
#  'A1877.jpg',
#  'A188.jpg',
#  'A1880.jpg',
#  'A1882.jpg',
#  'A1883.jpg',
#  'A1884.jpg',
#  'A1886.jpg',
#  'A1887.jpg',
#  'A1888.jpg',
#  'A1889.jpg',
#  'A189.jpg',
#  'A1892.jpg',
#  'A1893.jpg',
#  'A1894.jpg',
#  'A1895.jpg',
#  'A1896.jpg',
#  'A1898.jpg',
#  'A1899.jpg',
#  'A190.jpg',
#  'A1901.jpg',
#  'A1906.jpg',
#  'A1907.jpg',
#  'A1909.jpg',
#  'A191.jpg',
#  'A1913.jpg',
#  'A1914.jpg',
#  'A1915.jpg',
#  'A1918.jpg',
#  'A192.jpg',
#  'A1921.jpg',
#  'A1922.jpg',
#  'A1923.jpg',
#  'A1926.jpg',
#  'A1927.jpg',
#  'A1929.jpg',
#  'A193.jpg',
#  'A1932.jpg',
#  'A1933.jpg',
#  'A1935.jpg',
#  'A1939.jpg',
#  'A194.jpg',
#  'A1941.jpg',
#  'A1943.jpg',
#  'A1949.jpg',
#  'A1951.jpg',
#  'A1953.jpg',
#  'A1954.jpg',
#  'A1956.jpg',
#  'A1957.jpg',
#  'A1959.jpg',
#  'A196.jpg',
#  'A1961.jpg',
#  'A1963.jpg',
#  'A1965.jpg',
#  'A1966.jpg',
#  'A1967.jpg',
#  'A1968.jpg',
#  'A1970.jpg',
#  'A1972.jpg',
#  'A1974.jpg',
#  'A1977.jpg',
#  'A1979.jpg',
#  'A1981.jpg',
#  'A1982.jpg',
#  'A1984.jpg',
#  'A1985.jpg',
#  'A1988.jpg',
#  'A1989.jpg',
#  'A199.jpg',
#  'A1990.jpg',
#  'A1991.jpg',
#  'A1992.jpg',
#  'A1993.jpg',
#  'A1994.jpg',
#  'A1996.jpg',
#  'A1997.jpg',
#  'A1999.jpg',
#  'A200.jpg',
#  'A2000.jpg',
#  'A2001.jpg',
#  'A2002.jpg',
#  'A2004.jpg',
#  'A2005.jpg',
#  'A2007.jpg',
#  'A2009.jpg',
#  'A2010.jpg',
#  'A2011.jpg',
#  'A2012.jpg',
#  'A2016.jpg',
#  'A2018.jpg',
#  'A2019.jpg',
#  'A2022.jpg',
#  'A2023.jpg',
#  'A2026.jpg',
#  'A2027.jpg',
#  'A2028.jpg',
#  'A2029.jpg',
#  'A2031.jpg',
#  'A2032.jpg',
#  'A2033.jpg',
#  'A2034.jpg',
#  'A2036.jpg',
#  'A2037.jpg',
#  'A2038.jpg',
#  'A204.jpg',
#  'A2040.jpg',
#  'A2041.jpg',
#  'A2042.jpg',
#  'A2043.jpg',
#  'A2047.jpg',
#  'A2051.jpg',
#  'A2053.jpg',
#  'A2054.jpg',
#  'A2056.jpg',
#  'A2058.jpg',
#  'A2059.jpg',
#  'A2060.jpg',
#  'A2061.jpg',
#  'A2062.jpg',
#  'A2066.jpg',
#  'A2067.jpg',
#  'A207.jpg',
#  'A2071.jpg',
#  'A2072.jpg',
#  'A2077.jpg',
#  'A2078.jpg',
#  'A208.jpg',
#  'A2081.jpg',
#  'A2086.jpg',
#  'A2087.jpg',
#  'A2089.jpg',
#  'A209.jpg',
#  'A2090.jpg',
#  'A2091.jpg',
#  'A2093.jpg',
#  'A2094.jpg',
#  'A2096.jpg',
#  'A2097.jpg',
#  'A2098.jpg',
#  'A21.jpg',
#  'A210.jpg',
#  'A2100.jpg',
#  'A2103.jpg',
#  'A2104.jpg',
#  'A2105.jpg',
#  'A2107.jpg',
#  'A2108.jpg',
#  'A2109.jpg',
#  'A211.jpg',
#  'A2111.jpg',
#  'A2112.jpg',
#  'A2113.jpg',
#  'A2115.jpg',
#  'A2116.jpg',
#  'A212.jpg',
#  'A2122.jpg',
#  'A2123.jpg',
#  'A2125.jpg',
#  'A2129.jpg',
#  'A213.jpg',
#  'A2130.jpg',
#  'A2131.jpg',
#  'A2136.jpg',
#  'A2137.jpg',
#  'A2138.jpg',
#  'A2140.jpg',
#  'A2142.jpg',
#  'A2145.jpg',
#  'A2147.jpg',
#  'A2149.jpg',
#  'A2151.jpg',
#  'A2152.jpg',
#  'A2154.jpg',
#  'A2155.jpg',
#  'A2156.jpg',
#  'A2157.jpg',
#  'A2158.jpg',
#  'A2159.jpg',
#  'A216.jpg',
#  'A2160.jpg',
#  'A2161.jpg',
#  'A2162.jpg',
#  'A2165.jpg',
#  'A2166.jpg',
#  'A2169.jpg',
#  'A2176.jpg',
#  'A2177.jpg',
#  'A2178.jpg',
#  'A2179.jpg',
#  'A2180.jpg',
#  'A2183.jpg',
#  'A2185.jpg',
#  'A2187.jpg',
#  'A2188.jpg',
#  'A2189.jpg',
#  'A2190.jpg',
#  'A2191.jpg',
#  'A2192.jpg',
#  'A2193.jpg',
#  'A2194.jpg',
#  'A2195.jpg',
#  'A2196.jpg',
#  'A2198.jpg',
#  'A220.jpg',
#  'A2200.jpg',
#  'A2201.jpg',
#  'A2202.jpg',
#  'A2204.jpg',
#  'A2205.jpg',
#  'A2206.jpg',
#  'A2208.jpg',
#  'A2209.jpg',
#  'A2213.jpg',
#  'A2216.jpg',
#  'A2219.jpg',
#  'A2220.jpg',
#  'A2221.jpg',
#  'A2222.jpg',
#  'A2223.jpg',
#  'A2224.jpg',
#  'A2225.jpg',
#  'A2226.jpg',
#  'A2228.jpg',
#  'A223.jpg',
#  'A2231.jpg',
#  'A2232.jpg',
#  'A2233.jpg',
#  'A2234.jpg',
#  'A2235.jpg',
#  'A2237.jpg',
#  'A2241.jpg',
#  'A2244.jpg',
#  'A2245.jpg',
#  'A2246.jpg',
#  'A2247.jpg',
#  'A2248.jpg',
#  'A2249.jpg',
#  'A225.jpg',
#  'A2250.jpg',
#  'A2253.jpg',
#  'A2255.jpg',
#  'A2256.jpg',
#  'A2258.jpg',
#  'A226.jpg',
#  'A2261.jpg',
#  'A2262.jpg',
#  'A2265.jpg',
#  'A2266.jpg',
#  'A2267.jpg',
#  'A227.jpg',
#  'A2270.jpg',
#  'A2271.jpg',
#  'A2277.jpg',
#  'A228.jpg',
#  'A2281.jpg',
#  'A2282.jpg',
#  'A2284.jpg',
#  'A2286.jpg',
#  'A2288.jpg',
#  'A2289.jpg',
#  'A2290.jpg',
#  'A2293.jpg',
#  'A2296.jpg',
#  'A2297.jpg',
#  'A230.jpg',
#  'A2302.jpg',
#  'A2303.jpg',
#  'A2304.jpg',
#  'A2307.jpg',
#  'A2308.jpg',
#  'A2309.jpg',
#  'A231.jpg',
#  'A2310.jpg',
#  'A2311.jpg',
#  'A2314.jpg',
#  'A2315.jpg',
#  'A2316.jpg',
#  'A2317.jpg',
#  'A232.jpg',
#  'A2321.jpg',
#  'A2322.jpg',
#  'A2323.jpg',
#  'A2326.jpg',
#  'A2327.jpg',
#  'A2328.jpg',
#  'A233.jpg',
#  'A2330.jpg',
#  'A2331.jpg',
#  'A2332.jpg',
#  'A2336.jpg',
#  'A2337.jpg',
#  'A2338.jpg',
#  'A2340.jpg',
#  'A2341.jpg',
#  'A2344.jpg',
#  'A2345.jpg',
#  'A2347.jpg',
#  'A2348.jpg',
#  'A2349.jpg',
#  'A2350.jpg',
#  'A2351.jpg',
#  'A2354.jpg',
#  'A2355.jpg',
#  'A2356.jpg',
#  'A2358.jpg',
#  'A2359.jpg',
#  'A236.jpg',
#  'A2361.jpg',
#  'A2363.jpg',
#  'A2364.jpg',
#  'A2365.jpg',
#  'A2366.jpg',
#  'A2369.jpg',
#  'A237.jpg',
#  'A2373.jpg',
#  'A2375.jpg',
#  'A2376.jpg',
#  'A2378.jpg',
#  'A2379.jpg',
#  'A238.jpg',
#  'A2380.jpg',
#  'A2381.jpg',
#  'A2384.jpg',
#  'A2385.jpg',
#  'A2386.jpg',
#  'A2387.jpg',
#  'A2388.jpg',
#  'A2390.jpg',
#  'A2393.jpg',
#  'A2396.jpg',
#  'A2397.jpg',
#  'A2398.jpg',
#  'A2399.jpg',
#  'A24.jpg',
#  'A240.jpg',
#  'A2400.jpg',
#  'A2401.jpg',
#  'A2403.jpg',
#  'A2404.jpg',
#  'A2405.jpg',
#  'A2406.jpg',
#  'A241.jpg',
#  'A2410.jpg',
#  'A2412.jpg',
#  'A2414.jpg',
#  'A2416.jpg',
#  'A2417.jpg',
#  'A242.jpg',
#  'A2421.jpg',
#  'A2423.jpg',
#  'A2424.jpg',
#  'A2425.jpg',
#  'A2426.jpg',
#  'A2427.jpg',
#  'A2428.jpg',
#  'A2429.jpg',
#  'A2432.jpg',
#  'A2433.jpg',
#  'A2434.jpg',
#  'A2435.jpg',
#  'A2438.jpg',
#  'A2439.jpg',
#  'A2440.jpg',
#  'A2444.jpg',
#  'A2446.jpg',
#  'A2449.jpg',
#  'A245.jpg',
#  'A2452.jpg',
#  'A2455.jpg',
#  'A2456.jpg',
#  'A2457.jpg',
#  'A2458.jpg',
#  'A2460.jpg',
#  'A2461.jpg',
#  'A2463.jpg',
#  'A2469.jpg',
#  'A2470.jpg',
#  'A2472.jpg',
#  'A2474.jpg',
#  'A2475.jpg',
#  'A2477.jpg',
#  'A248.jpg',
#  'A2480.jpg',
#  'A2484.jpg',
#  'A2487.jpg',
#  'A2492.jpg',
#  'A2493.jpg',
#  'A2494.jpg',
#  'A2495.jpg',
#  'A2496.jpg',
#  'A2497.jpg',
#  'A2499.jpg',
#  'A25.jpg',
#  'A250.jpg',
#  'A2500.jpg',
#  'A2501.jpg',
#  'A2503.jpg',
#  'A2504.jpg',
#  'A2507.jpg',
#  'A2508.jpg',
#  'A2509.jpg',
#  'A251.jpg',
#  'A2510.jpg',
#  'A2512.jpg',
#  'A2514.jpg',
#  'A2515.jpg',
#  'A2517.jpg',
#  'A2518.jpg',
#  'A2520.jpg',
#  'A2522.jpg',
#  'A2523.jpg',
#  'A2524.jpg',
#  'A2525.jpg',
#  'A2526.jpg',
#  'A2527.jpg',
#  'A2528.jpg',
#  'A2529.jpg',
#  'A2530.jpg',
#  ...]

# %%
# This is the number of classes in which we have to classify our images (in this case 29, the letters of the alphabet and
# some other signs).
class_count = len(result.keys())

# %%
print(class_count)
# Out:
# 29

# %%
"""
Here I take the already splitted data returned by the function 'create_image_lists()' and I put each image path into 
two different lists, according to the related sign.
"""
train_data = []
validation_data = []

for val in result.keys():
    train_data.append(result[val]['training'])
    
for val in result.keys():
    validation_data.append(result[val]['validation'])

print(train_data)
print(validation_data)
# Out:
# [['A10.jpg', 'A100.jpg', 'A1001.jpg', 'A1003.jpg', 'A1004.jpg', 'A1005.jpg', 'A1007.jpg', 'A1008.jpg', 'A1009.jpg', 'A1010.jpg', 'A1011.jpg', 'A1013.jpg', 'A1016.jpg', 'A1017.jpg', 'A1018.jpg', 'A1020.jpg', 'A1022.jpg', 'A1025.jpg', 'A1026.jpg', 'A1028.jpg', 'A103.jpg', 'A1030.jpg', 'A1031.jpg', 'A1032.jpg', 'A1033.jpg', 'A1037.jpg', 'A1038.jpg', 'A1039.jpg', 'A1042.jpg', 'A1043.jpg', 'A1045.jpg', 'A1046.jpg', 'A1048.jpg', 'A1050.jpg', 'A1054.jpg', 'A1056.jpg', 'A1057.jpg', 'A1058.jpg', 'A1061.jpg', 'A1063.jpg', 'A1064.jpg', 'A1065.jpg', 'A1066.jpg', 'A1067.jpg', 'A1068.jpg', 'A1069.jpg', 'A1070.jpg', 'A1071.jpg', 'A1072.jpg', 'A1074.jpg', 'A1075.jpg', 'A1076.jpg', 'A1077.jpg', 'A108.jpg', 'A1081.jpg', 'A1083.jpg', 'A1085.jpg', 'A1086.jpg', 'A1088.jpg', 'A1089.jpg', 'A109.jpg', 'A1090.jpg', 'A1092.jpg', 'A1093.jpg', 'A1095.jpg', 'A1096.jpg', 'A1097.jpg', 'A1099.jpg', 'A110.jpg', 'A1100.jpg', 'A1101.jpg', 'A1104.jpg', 'A1105.jpg', 'A1106.jpg', 'A1107.jpg', 'A1108.jpg', 'A1109.jpg', 'A1110.jpg', 'A1111.jpg', 'A1112.jpg', 'A1113.jpg', 'A1117.jpg', 'A1118.jpg', 'A1120.jpg', 'A1121.jpg', 'A1122.jpg', 'A1123.jpg', 'A1128.jpg', 'A1129.jpg', 'A113.jpg', 'A1132.jpg', 'A1133.jpg', 'A1135.jpg', 'A1136.jpg', 'A1137.jpg', 'A1139.jpg', 'A114.jpg', 'A1140.jpg', 'A1141.jpg', 'A1142.jpg', 'A1143.jpg', 'A1145.jpg', 'A1146.jpg', 'A1147.jpg', 'A1148.jpg', 'A1151.jpg', 'A1152.jpg', 'A1153.jpg', 'A1155.jpg', 'A1158.jpg', 'A116.jpg', 'A1165.jpg', 'A1166.jpg', 'A1167.jpg', 'A1168.jpg', 'A1169.jpg', 'A117.jpg', 'A1174.jpg', 'A1175.jpg', 'A1176.jpg', 'A1177.jpg', 'A1178.jpg', 'A1179.jpg', 'A118.jp
.jpg', 'A2124.jpg', 'A2127.jpg', 'A2133.jpg', 'A2134.jpg', 'A214.jpg', 'A2141.jpg', 'A2144.jpg', 'A2148.jpg', 'A215.jpg', 'A2163.jpg', 'A2167.jpg', 'A2168.jpg', 'A217.jpg', 'A2170.jpg', 'A2172.jpg', 'A2173.jpg', 'A2174.jpg', 'A2175.jpg', 'A218.jpg', 'A2182.jpg', 'A2197.jpg', 'A2199.jpg', 'A2203.jpg', 'A2210.jpg', 'A2211.jpg', 'A2215.jpg', 'A2217.jpg', 'A222.jpg', 'A2227.jpg', 'A2230.jpg', 'A2236.jpg', 'A2238.jpg', 'A2242.jpg', 'A2243.jpg', 'A2254.jpg', 'A2257.jpg', 'A2259.jpg', 'A2260.jpg', 'A2263.jpg', 'A2268.jpg', 'A2274.jp ...

# %%
"""
I wrote this two 'for' cycles to split the data into two folders --> 'train_data' and 'validation_data', which I'll use for the
training phase.
"""

for i in range(len(train_data)):
    for filename in train_data[i]:
        path = "dataset/" + list(result.keys())[i].upper() + "/" + filename 
        new_path = "train_data/" + list(result.keys())[i] + "/" + filename
        img = cv2.imread(path, 0)
        cv2.imwrite(new_path, img)
        
for i in range(len(validation_data)):
    for filename in validation_data[i]:
        path = "dataset/" + list(result.keys())[i].upper() + "/" + filename 
        new_path = "validation_data/" + list(result.keys())[i] + "/" + filename
        img = cv2.imread(path, 0)
        cv2.imwrite(new_path, img)

# %%
"""
This is the core of the project, the CNN architecture.
Nothing special, actually. Until now, I haven't tried other combinations.
"""
def create_model():
    K.set_image_dim_ordering('tf')

    model = Sequential()
    model.add(Conv2D(32, (3, 3), input_shape=(200, 200, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    model.add(Dense(29))
    model.add(Activation('softmax'))
    
    return model

# %%
model = create_model()

batch_size = 64

# This is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        horizontal_flip=True)

# This is the augmentation configuration we will use for testing:
test_datagen = ImageDataGenerator(rescale=1./255)

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

train_generator = train_datagen.flow_from_directory(
        'train_data', 
        target_size=(200, 200),
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        'validation_data',
        target_size=(200, 200),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 52252 images belonging to 29 classes.
# Found 17309 images belonging to 29 classes.

# %%
# Let's start training!
model.fit_generator(
        train_generator,
        steps_per_epoch=2000 // batch_size,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=800 // batch_size)
model.save_weights('first_try.h5')  # Always save your weights after training or during training

"""I used 'FloydHub' to train the network, reaching an accuracy of about 80% with 50 epochs."""

# %%
def load_trained_model(weights_path):
    final_model = create_model()
    final_model.load_weights(weights_path)
    return final_model

# %%
# Once trained, let's use the optimized weights to create a new model and test it out!
load_model = load_trained_model("first_try.h5")
load_model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Here I simply put some images into the directory 'test_data' and predict the result
for i in range(20):
    img = cv2.imread('test_data/F' + str(i+1) + '.jpg')
    if (img is not None):
        img = np.expand_dims(img, axis=0)
        result_class = load_model.predict_classes(img)
        print(list(result.keys())[result_class[0]].upper())
# Out:
# F
# F
# F
# F
# F
# F
